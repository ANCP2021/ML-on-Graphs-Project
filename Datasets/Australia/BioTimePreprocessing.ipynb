# %%
import pandas as pd

df = pd.read_csv('BioTIMEQuery_24_06_2021.csv')
# Out:
# C:\Users\dxl702\AppData\Local\Temp\ipykernel_2444\2742718459.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('BioTIMEQuery_24_06_2021.csv')

# %%
display(df)
# Out:
#          Unnamed: 0  STUDY_ID  DAY  MONTH  YEAR  \
# 0                 1        10  NaN    NaN  1984
# 1                 2        10  NaN    NaN  1984
# 2                 3        10  NaN    NaN  1984
# 3                 4        10  NaN    NaN  1984
# 4                 5        10  NaN    NaN  1984
# ...             ...       ...  ...    ...   ...
# 8552244    26178100       548  NaN    NaN  2007
# 8552245    26179100       548  NaN    NaN  2009
# 8552246    26180100       548  NaN    NaN  2012
# 8552247    26181100       548  NaN    NaN  2007
# 8552248    26182100       548  NaN    NaN  2011
#
#                                           SAMPLE_DESC   PLOT  ID_SPECIES  \
# 0            47.400000_-95.120000_12_Control_0_Medium     12          22
# 1            47.400000_-95.120000_12_Control_0_Medium     12          23
# 2            47.400000_-95.120000_12_Control_0_Medium     12          24
# 3            47.400000_-95.120000_12_Control_0_Medium     12         607
# ...

# %%
df.LATITUDE.unique()
# Out:
# array([47.4    , 44.33   , 50.25   , ..., 49.10048, 49.0988 , 49.09058])

# %%
lat = df['LATITUDE']
long = df['LONGITUDE']

australia = df[lat.between(-44, -9, inclusive='both') & long.between(112, 154, inclusive='both')]

# %%
australia
# Out:
#          Unnamed: 0  STUDY_ID   DAY  MONTH  YEAR  \
# 313019       313323        99  10.0   10.0  1983
# 313020       313324        99  10.0   10.0  1983
# 313021       313325        99  10.0   10.0  1983
# 313022       313326        99  10.0   10.0  1983
# 313023       313327        99  10.0   10.0  1983
# ...             ...       ...   ...    ...   ...
# 8389177     8410359       503   6.0    3.0  2015
# 8389178     8410360       503   6.0    3.0  2015
# 8389179     8410361       503   6.0    3.0  2015
# 8389180     8410362       503   6.0    3.0  2015
# 8389181     8410363       503   6.0    3.0  2015
#
#                                                SAMPLE_DESC      PLOT  \
# 313019   -18.849200_117.872000_Soela_survey_SO_5/83_sta...       NaN
# 313020   -18.849200_117.872000_Soela_survey_SO_5/83_sta...       NaN
# 313021   -18.849200_117.872000_Soela_survey_SO_5/83_sta...       NaN
# 313022   -18.994200_117.816000_Soela_survey_SO_5/83_sta...       NaN
# ...

# %%
australia.to_csv('australiaBioTime.csv')
